# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *

# %%
def model_arch():
  model = Sequential()
  model.add(Flatten(input_shape=(28,28)))
  model.add(Dense(128, activation='relu'))
  model.add(Dense(10, activation='softmax'))
  print(model.summary())
  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
model = model_arch()
history = model.fit(x=train_images, y=train_labels, validation_split=0.2, epochs=10, batch_size=1, verbose=1, validation_data=(test_images, test_labels))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4925 - accuracy: 0.8256
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3719 - accuracy: 0.8651
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3352 - accuracy: 0.8763
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3096 - accuracy: 0.8860
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2937 - accuracy: 0.8917
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2768 - accuracy: 0.8973
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2687 - accuracy: 0.9015
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2555 - accuracy: 0.9043
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2467 - accuracy: 0.9087
# Epoch 10/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2361 - accuracy: 0.9114
# Epoch 1/10
# 60000/60000 [==============================] - 238s 4ms/step - loss: 0.4207 - accuracy: 0.8540 - val_loss: 0.4228 - val_accuracy: 0.8568
# Epoch 2/10
# 60000/60000 [==============================] - 235s 4ms/step - loss: 0.3931 - accuracy: 0.8650 - val_loss: 0.5527 - val_accuracy: 0.8367
# Epoch 3/10
# 60000/60000 [==============================] - 238s 4ms/step - loss: 0.3804 - accuracy: 0.8698 - val_loss: 0.4437 - val_accuracy: 0.8545
# Epoch 4/10
# 60000/60000 [==============================] - 229s 4ms/step - loss: 0.3654 - accuracy: 0.8758 - val_loss: 0.4860 - val_accuracy: 0.8505
# Epoch 5/10
# 60000/60000 [==============================] - 240s 4ms/step - loss: 0.3610 - accuracy: 0.8781 - val_loss: 0.4653 - val_accuracy: 0.8568
# Epoch 6/10
# 60000/60000 [==============================] - 240s 4ms/step - loss: 0.3582 - accuracy: 0.8798 - val_loss: 0.5672 - val_accuracy: 0.8526
# Epoch 7/10
# 60000/60000 [==============================] - 240s 4ms/step - loss: 0.3555 - accuracy: 0.8825 - val_loss: 0.4796 - val_accuracy: 0.8625
# Epoch 8/10
# 60000/60000 [==============================] - 228s 4ms/step - loss: 0.3498 - accuracy: 0.8843 - val_loss: 0.4600 - val_accuracy: 0.8674
# Epoch 9/10
# 60000/60000 [==============================] - 241s 4ms/step - loss: 0.3442 - accuracy: 0.8870 - val_loss: 0.5132 - val_accuracy: 0.8597
# Epoch 10/10
# 60000/60000 [==============================] - 241s 4ms/step - loss: 0.3404 - accuracy: 0.8877 - val_loss: 0.5242 - val_accuracy: 0.8619

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Test Accuracy: ", test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5242 - accuracy: 0.8619
# Test Accuracy:  0.8618999719619751

# %%
predictions = model.predict(test_images)
predict_labels = np.argmax(predictions, axis=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
num_rows = 5
num_cols = 5
num_images = num_rows * num_cols

# %%
plt.figure(figsize = (2*2*num_cols, 2*num_rows))

# %%
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i + 1)
  plt.imshow(test_images[i], cmap='gray')
  plt.axis('off')
  plt.subplot(num_rows, 2*num_cols, 2*i + 2)
  plt.bar(range(10), predictions[i])
  plt.xticks(range(10))
  plt.ylim([0,1])
  plt.tight_layout()
  plt.title("Predicted label: {predicted_labels[i]}")
  plt.show()
